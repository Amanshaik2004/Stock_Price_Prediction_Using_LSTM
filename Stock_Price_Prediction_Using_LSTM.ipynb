# %% [markdown]
# ### AUTHOR : Shaik Mohammed Aman

# %% [markdown]
# ## STEP 1 : IMPORTING LIBRARIES AND DATA TO BE USED

# %%
#importing libraries to be used
import numpy as np # for linear algebra
import pandas as pd # data preprocessing
import matplotlib.pyplot as plt # data visualization library
import seaborn as sns # data visualization library
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore') # ignore warnings 

from sklearn.preprocessing import MinMaxScaler # for normalization
from keras.models import Sequential
from keras.layers import Dense, Dropout, LSTM, Bidirectional

# %%
df = pd.read_csv('Stockdataset.csv') # data_importing
df.head(10) # fetching first 10 rows of dataset
# Out:
#   symbol                       date   close    high       low    open  \
# 0   GOOG  2016-06-14 00:00:00+00:00  718.27  722.47  713.1200  716.48
# 1   GOOG  2016-06-15 00:00:00+00:00  718.92  722.98  717.3100  719.00
# 2   GOOG  2016-06-16 00:00:00+00:00  710.36  716.65  703.2600  714.91
# 3   GOOG  2016-06-17 00:00:00+00:00  691.72  708.82  688.4515  708.65
# 4   GOOG  2016-06-20 00:00:00+00:00  693.71  702.48  693.4100  698.77
# 5   GOOG  2016-06-21 00:00:00+00:00  695.94  702.77  692.0100  698.40
# 6   GOOG  2016-06-22 00:00:00+00:00  697.46  700.86  693.0819  699.06
# 7   GOOG  2016-06-23 00:00:00+00:00  701.87  701.95  687.0000  697.45
# 8   GOOG  2016-06-24 00:00:00+00:00  675.22  689.40  673.4500  675.17
# 9   GOOG  2016-06-27 00:00:00+00:00  668.26  672.30  663.2840  671.00
#
#     volume  adjClose  adjHigh    adjLow  adjOpen  adjVolume  divCash  \
# 0  1306065    718.27   722.47  713.1200   716.48    1306065      0.0
# 1  1214517    718.92   722.98  717.3100   719.00    1214517      0.0
# 2  1982471    710.36   716.65  703.2600   714.91    1982471      0.0
# 3  3402357    691.72   708.82  688.4515   708.65    3402357      0.0
# 4  2082538    693.71   702.48  693.4100   698.77    2082538      0.0
# 5  1465634    695.94   702.77  692.0100   698.40    1465634      0.0
# 6  1184318    697.46   700.86  693.0819   699.06    1184318      0.0
# 7  2171415    701.87   701.95  687.0000   697.45    2171415      0.0
# 8  4449022    675.22   689.40  673.4500   675.17    4449022      0.0
# 9  2641085    668.26   672.30  663.2840   671.00    2641085      0.0
#
#    splitFactor
# 0          1.0
# 1          1.0
# 2          1.0
# 3          1.0
# 4          1.0
# 5          1.0
# 6          1.0
# 7          1.0
# 8          1.0
# 9          1.0

# %% [markdown]
# ## STEP 2 : GATHERING INSIGHTS

# %%
# shape of data
print("Shape of data:",df.shape)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 # shape of data
# ----> 2 print("Shape of data:",df.shape)
#
# NameError: name 'df' is not defined

# %%
# statistical description of data
df.describe()
# Out:
#              close         high          low         open        volume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430934  1204.176430  1215.260779  1.601590e+06
# std     383.333358   387.570872   378.777094   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#           adjClose      adjHigh       adjLow      adjOpen     adjVolume  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1.258000e+03
# mean   1216.317067  1227.430936  1204.176436  1215.260779  1.601590e+06
# std     383.333358   387.570873   378.777099   382.446995  6.960172e+05
# min     668.260000   672.300000   663.284000   671.000000  3.467530e+05
# 25%     960.802500   968.757500   952.182500   959.005000  1.173522e+06
# 50%    1132.460000  1143.935000  1117.915000  1131.150000  1.412588e+06
# 75%    1360.595000  1374.345000  1348.557500  1361.075000  1.812156e+06
# max    2521.600000  2526.990000  2498.290000  2524.920000  6.207027e+06
#
#        divCash  splitFactor
# count   1258.0       1258.0
# mean       0.0          1.0
# std        0.0          0.0
# min        0.0          1.0
# 25%        0.0          1.0
# 50%        0.0          1.0
# 75%        0.0          1.0
# max        0.0          1.0

# %%
# summary of data
df.info()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 2
#       1 # summary of data
# ----> 2 df.info()
#
# NameError: name 'df' is not defined

# %%
# checking null values
df.isnull().sum()
# Out:
# symbol         0
# date           0
# close          0
# high           0
# low            0
# open           0
# volume         0
# adjClose       0
# adjHigh        0
# adjLow         0
# adjOpen        0
# adjVolume      0
# divCash        0
# splitFactor    0
# dtype: int64

# %% [markdown]
# ### There are no null values in the dataset

# %%
df = df[['date','open','close']] # Extracting required columns
df['date'] = pd.to_datetime(df['date'].apply(lambda x: x.split()[0])) # converting object dtype of date column to datetime dtype
df.set_index('date',drop=True,inplace=True) # Setting date column as index
df.head(10)
# Out:
#               open   close
# date
# 2016-06-14  716.48  718.27
# 2016-06-15  719.00  718.92
# 2016-06-16  714.91  710.36
# 2016-06-17  708.65  691.72
# 2016-06-20  698.77  693.71
# 2016-06-21  698.40  695.94
# 2016-06-22  699.06  697.46
# 2016-06-23  697.45  701.87
# 2016-06-24  675.17  675.22
# 2016-06-27  671.00  668.26

# %%
# plotting open and closing price on date index
fig, ax =plt.subplots(1,2,figsize=(20,7))
ax[0].plot(df['open'],label='Open',color='green')
ax[0].set_xlabel('Date',size=15)
ax[0].set_ylabel('Price',size=15)
ax[0].legend()

ax[1].plot(df['close'],label='Close',color='red')
ax[1].set_xlabel('Date',size=15)
ax[1].set_ylabel('Price',size=15)
ax[1].legend()

fig.show()

# %% [markdown]
# ### DATA PRE-PROCESSING

# %%
# normalizing all the values of all columns using MinMaxScaler
MMS = MinMaxScaler()
df[df.columns] = MMS.fit_transform(df)
df.head(10)
# Out:
#                 open     close
# date
# 2016-06-14  0.024532  0.026984
# 2016-06-15  0.025891  0.027334
# 2016-06-16  0.023685  0.022716
# 2016-06-17  0.020308  0.012658
# 2016-06-20  0.014979  0.013732
# 2016-06-21  0.014779  0.014935
# 2016-06-22  0.015135  0.015755
# 2016-06-23  0.014267  0.018135
# 2016-06-24  0.002249  0.003755
# 2016-06-27  0.000000  0.000000

# %%
# splitting the data into training and test set
training_size = round(len(df) * 0.75) # Selecting 75 % for training and 25 % for testing
training_size
# Out:
# 944

# %%
train_data = df[:training_size]
test_data  = df[training_size:]

train_data.shape, test_data.shape
# Out:
# ((944, 2), (314, 2))

# %%
# Function to create sequence of data for training and testing

def create_sequence(dataset):
  sequences = []
  labels = []

  start_idx = 0

  for stop_idx in range(50,len(dataset)): # Selecting 50 rows at a time
    sequences.append(dataset.iloc[start_idx:stop_idx])
    labels.append(dataset.iloc[stop_idx])
    start_idx += 1
  return (np.array(sequences),np.array(labels))

# %%
train_seq, train_label = create_sequence(train_data) 
test_seq, test_label = create_sequence(test_data)
train_seq.shape, train_label.shape, test_seq.shape, test_label.shape
# Out:
# ((894, 50, 2), (894, 2), (264, 50, 2), (264, 2))

# %% [markdown]
# ##   CREATING LSTM MODEL

# %%
# imported Sequential from keras.models 
model = Sequential()
# importing Dense, Dropout, LSTM, Bidirectional from keras.layers 
model.add(LSTM(units=50, return_sequences=True, input_shape = (train_seq.shape[1], train_seq.shape[2])))

model.add(Dropout(0.1)) 
model.add(LSTM(units=50))

model.add(Dense(2))

model.compile(loss='mean_squared_error', optimizer='adam', metrics=['mean_absolute_error'])

model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 50, 50)         │        10,600 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 50, 50)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 50)             │        20,200 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 2)              │           102 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 30,902 (120.71 KB)
#  Trainable params: 30,902 (120.71 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# fitting the model by iterating the dataset over 100 times(100 epochs)
model.fit(train_seq, train_label, epochs=100,validation_data=(test_seq, test_label), verbose=1)
# Out:
# Epoch 1/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.7778e-05 - mean_absolute_error: 0.0060 - val_loss: 9.3380e-04 - val_mean_absolute_error: 0.0221
# Epoch 2/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.1986e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 3/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.2988e-05 - mean_absolute_error: 0.0061 - val_loss: 7.1524e-04 - val_mean_absolute_error: 0.0193
# Epoch 4/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 7.6414e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0018 - val_mean_absolute_error: 0.0325
# Epoch 5/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.4245e-05 - mean_absolute_error: 0.0059 - val_loss: 8.6755e-04 - val_mean_absolute_error: 0.0210
# Epoch 6/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 7.8905e-05 - mean_absolute_error: 0.0059 - val_loss: 8.4808e-04 - val_mean_absolute_error: 0.0210
# Epoch 7/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 9.1934e-05 - mean_absolute_error: 0.0066 - val_loss: 6.7484e-04 - val_mean_absolute_error: 0.0187
# Epoch 8/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 85ms/step - loss: 8.3776e-05 - mean_absolute_error: 0.0063 - val_loss: 8.1188e-04 - val_mean_absolute_error: 0.0205
# Epoch 9/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 101ms/step - loss: 7.7097e-05 - mean_absolute_error: 0.0062 - val_loss: 9.8307e-04 - val_mean_absolute_error: 0.0224
# Epoch 10/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 93ms/step - loss: 1.0500e-04 - mean_absolute_error: 0.0068 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 11/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 8.0403e-05 - mean_absolute_error: 0.0059 - val_loss: 7.4285e-04 - val_mean_absolute_error: 0.0202
# Epoch 12/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 83ms/step - loss: 7.7914e-05 - mean_absolute_error: 0.0060 - val_loss: 6.9562e-04 - val_mean_absolute_error: 0.0190
# Epoch 13/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 87ms/step - loss: 8.2102e-05 - mean_absolute_error: 0.0060 - val_loss: 6.1038e-04 - val_mean_absolute_error: 0.0180
# Epoch 14/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 7.8991e-05 - mean_absolute_error: 0.0060 - val_loss: 7.7854e-04 - val_mean_absolute_error: 0.0198
# Epoch 15/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 9.3525e-05 - mean_absolute_error: 0.0066 - val_loss: 9.8694e-04 - val_mean_absolute_error: 0.0231
# Epoch 16/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 1.0770e-04 - mean_absolute_error: 0.0076 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 17/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 8.5123e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0010 - val_mean_absolute_error: 0.0239
# Epoch 18/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 7.9358e-05 - mean_absolute_error: 0.0059 - val_loss: 7.5877e-04 - val_mean_absolute_error: 0.0200
# Epoch 19/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 8.3334e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0011 - val_mean_absolute_error: 0.0249
# Epoch 20/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 9.0120e-05 - mean_absolute_error: 0.0060 - val_loss: 8.3650e-04 - val_mean_absolute_error: 0.0213
# Epoch 21/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 9.2330e-05 - mean_absolute_error: 0.0060 - val_loss: 7.2573e-04 - val_mean_absolute_error: 0.0195
# Epoch 22/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 6.9725e-05 - mean_absolute_error: 0.0055 - val_loss: 0.0016 - val_mean_absolute_error: 0.0306
# Epoch 23/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.2452e-05 - mean_absolute_error: 0.0059 - val_loss: 8.8991e-04 - val_mean_absolute_error: 0.0218
# Epoch 24/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 7.8837e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0017 - val_mean_absolute_error: 0.0318
# Epoch 25/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 8.4131e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0013 - val_mean_absolute_error: 0.0278
# Epoch 26/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 7.1999e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0012 - val_mean_absolute_error: 0.0266
# Epoch 27/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 6.9258e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0014 - val_mean_absolute_error: 0.0291
# Epoch 28/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 7.1008e-05 - mean_absolute_error: 0.0057 - val_loss: 8.3811e-04 - val_mean_absolute_error: 0.0219
# Epoch 29/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 71ms/step - loss: 7.0148e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0021 - val_mean_absolute_error: 0.0375
# Epoch 30/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.9419e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0011 - val_mean_absolute_error: 0.0247
# Epoch 31/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 7.9431e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0021 - val_mean_absolute_error: 0.0366
# Epoch 32/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.5144e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 33/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 7.6527e-05 - mean_absolute_error: 0.0059 - val_loss: 7.7212e-04 - val_mean_absolute_error: 0.0198
# Epoch 34/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 9.2533e-05 - mean_absolute_error: 0.0064 - val_loss: 9.7498e-04 - val_mean_absolute_error: 0.0223
# Epoch 35/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 8.1194e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0020 - val_mean_absolute_error: 0.0333
# Epoch 36/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 8.0561e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0011 - val_mean_absolute_error: 0.0237
# Epoch 37/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 7.4476e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0011 - val_mean_absolute_error: 0.0244
# Epoch 38/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.8217e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0016 - val_mean_absolute_error: 0.0317
# Epoch 39/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 9.8054e-05 - mean_absolute_error: 0.0069 - val_loss: 0.0015 - val_mean_absolute_error: 0.0303
# Epoch 40/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 8.0142e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0013 - val_mean_absolute_error: 0.0280
# Epoch 41/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.5024e-05 - mean_absolute_error: 0.0056 - val_loss: 6.0429e-04 - val_mean_absolute_error: 0.0176
# Epoch 42/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 6.8093e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0013 - val_mean_absolute_error: 0.0270
# Epoch 43/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 73ms/step - loss: 7.3012e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 44/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 7.3738e-05 - mean_absolute_error: 0.0058 - val_loss: 5.3595e-04 - val_mean_absolute_error: 0.0166
# Epoch 45/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.6836e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 46/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.5973e-05 - mean_absolute_error: 0.0058 - val_loss: 6.7701e-04 - val_mean_absolute_error: 0.0186
# Epoch 47/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 6.3965e-05 - mean_absolute_error: 0.0054 - val_loss: 7.7846e-04 - val_mean_absolute_error: 0.0201
# Epoch 48/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 9.0173e-05 - mean_absolute_error: 0.0063 - val_loss: 5.8438e-04 - val_mean_absolute_error: 0.0172
# Epoch 49/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 8.1266e-05 - mean_absolute_error: 0.0059 - val_loss: 7.7807e-04 - val_mean_absolute_error: 0.0197
# Epoch 50/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 6.5590e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0012 - val_mean_absolute_error: 0.0249
# Epoch 51/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.2996e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0011 - val_mean_absolute_error: 0.0235
# Epoch 52/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 8.9275e-05 - mean_absolute_error: 0.0065 - val_loss: 8.6807e-04 - val_mean_absolute_error: 0.0210
# Epoch 53/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 8.2368e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0019 - val_mean_absolute_error: 0.0326
# Epoch 54/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 7.0577e-05 - mean_absolute_error: 0.0057 - val_loss: 7.7420e-04 - val_mean_absolute_error: 0.0205
# Epoch 55/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 6.9672e-05 - mean_absolute_error: 0.0057 - val_loss: 8.5949e-04 - val_mean_absolute_error: 0.0212
# Epoch 56/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 6.8325e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0012 - val_mean_absolute_error: 0.0255
# Epoch 57/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 75ms/step - loss: 7.2888e-05 - mean_absolute_error: 0.0057 - val_loss: 9.5993e-04 - val_mean_absolute_error: 0.0224
# Epoch 58/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 6.0223e-05 - mean_absolute_error: 0.0051 - val_loss: 0.0017 - val_mean_absolute_error: 0.0313
# Epoch 59/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 81ms/step - loss: 8.1634e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0010 - val_mean_absolute_error: 0.0231
# Epoch 60/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 6.5024e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0018 - val_mean_absolute_error: 0.0340
# Epoch 61/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 8.2921e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0013 - val_mean_absolute_error: 0.0274
# Epoch 62/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 9.0763e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0011 - val_mean_absolute_error: 0.0238
# Epoch 63/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.2337e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 64/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 7.0141e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0012 - val_mean_absolute_error: 0.0240
# Epoch 65/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 7.3843e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0013 - val_mean_absolute_error: 0.0263
# Epoch 66/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 6.9763e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0018 - val_mean_absolute_error: 0.0317
# Epoch 67/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 82ms/step - loss: 8.1141e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0013 - val_mean_absolute_error: 0.0251
# Epoch 68/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 9.0729e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0017 - val_mean_absolute_error: 0.0317
# Epoch 69/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 84ms/step - loss: 8.5915e-05 - mean_absolute_error: 0.0063 - val_loss: 0.0012 - val_mean_absolute_error: 0.0258
# Epoch 70/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 7.7139e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0012 - val_mean_absolute_error: 0.0253
# Epoch 71/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 6.3277e-05 - mean_absolute_error: 0.0054 - val_loss: 0.0018 - val_mean_absolute_error: 0.0321
# Epoch 72/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.0414e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0013 - val_mean_absolute_error: 0.0256
# Epoch 73/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 6.8548e-05 - mean_absolute_error: 0.0057 - val_loss: 9.4111e-04 - val_mean_absolute_error: 0.0214
# Epoch 74/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 86ms/step - loss: 7.4603e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0012 - val_mean_absolute_error: 0.0259
# Epoch 75/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 7.1401e-05 - mean_absolute_error: 0.0059 - val_loss: 8.2988e-04 - val_mean_absolute_error: 0.0206
# Epoch 76/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 8.6196e-05 - mean_absolute_error: 0.0062 - val_loss: 0.0013 - val_mean_absolute_error: 0.0269
# Epoch 77/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.8929e-05 - mean_absolute_error: 0.0058 - val_loss: 0.0011 - val_mean_absolute_error: 0.0242
# Epoch 78/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.1966e-05 - mean_absolute_error: 0.0059 - val_loss: 7.1768e-04 - val_mean_absolute_error: 0.0189
# Epoch 79/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 83ms/step - loss: 7.2620e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0011 - val_mean_absolute_error: 0.0233
# Epoch 80/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 3s 98ms/step - loss: 8.1173e-05 - mean_absolute_error: 0.0062 - val_loss: 8.2938e-04 - val_mean_absolute_error: 0.0201
# Epoch 81/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 79ms/step - loss: 8.3947e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0011 - val_mean_absolute_error: 0.0241
# Epoch 82/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 6.9595e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0012 - val_mean_absolute_error: 0.0250
# Epoch 83/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.9191e-05 - mean_absolute_error: 0.0061 - val_loss: 0.0016 - val_mean_absolute_error: 0.0287
# Epoch 84/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 85ms/step - loss: 7.7191e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0010 - val_mean_absolute_error: 0.0224
# Epoch 85/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.1653e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0015 - val_mean_absolute_error: 0.0287
# Epoch 86/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 8.3808e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0022 - val_mean_absolute_error: 0.0362
# Epoch 87/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 81ms/step - loss: 7.5009e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0013 - val_mean_absolute_error: 0.0264
# Epoch 88/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 7.8224e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0012 - val_mean_absolute_error: 0.0268
# Epoch 89/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 9.4141e-05 - mean_absolute_error: 0.0067 - val_loss: 0.0014 - val_mean_absolute_error: 0.0278
# Epoch 90/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.9608e-05 - mean_absolute_error: 0.0059 - val_loss: 6.7876e-04 - val_mean_absolute_error: 0.0184
# Epoch 91/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 6.6880e-05 - mean_absolute_error: 0.0056 - val_loss: 0.0012 - val_mean_absolute_error: 0.0250
# Epoch 92/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 72ms/step - loss: 6.6044e-05 - mean_absolute_error: 0.0056 - val_loss: 7.3576e-04 - val_mean_absolute_error: 0.0194
# Epoch 93/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 73ms/step - loss: 8.2934e-05 - mean_absolute_error: 0.0060 - val_loss: 0.0012 - val_mean_absolute_error: 0.0250
# Epoch 94/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 7.2915e-05 - mean_absolute_error: 0.0057 - val_loss: 8.2039e-04 - val_mean_absolute_error: 0.0198
# Epoch 95/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 80ms/step - loss: 8.0918e-05 - mean_absolute_error: 0.0059 - val_loss: 0.0010 - val_mean_absolute_error: 0.0225
# Epoch 96/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 78ms/step - loss: 8.9603e-05 - mean_absolute_error: 0.0066 - val_loss: 0.0013 - val_mean_absolute_error: 0.0251
# Epoch 97/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 76ms/step - loss: 6.5918e-05 - mean_absolute_error: 0.0055 - val_loss: 9.8633e-04 - val_mean_absolute_error: 0.0220
# Epoch 98/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 6.5925e-05 - mean_absolute_error: 0.0057 - val_loss: 0.0012 - val_mean_absolute_error: 0.0245
# Epoch 99/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 77ms/step - loss: 8.2697e-05 - mean_absolute_error: 0.0063 - val_loss: 8.2190e-04 - val_mean_absolute_error: 0.0204
# Epoch 100/100
# 28/28 ━━━━━━━━━━━━━━━━━━━━ 2s 74ms/step - loss: 8.0374e-05 - mean_absolute_error: 0.0064 - val_loss: 0.0019 - val_mean_absolute_error: 0.0307

# %%
# predicting the values after running the model
test_predicted = model.predict(test_seq)
test_predicted[:5]
# Out:
# 9/9 ━━━━━━━━━━━━━━━━━━━━ 2s 162ms/step
# array([[0.40822774, 0.40704027],
#        [0.40756047, 0.40642142],
#        [0.40684652, 0.4054176 ],
#        [0.41391194, 0.41196567],
#        [0.4144581 , 0.41281494]], dtype=float32)

# %%
# Inversing normalization/scaling on predicted data 
test_inverse_predicted = MMS.inverse_transform(test_predicted)
test_inverse_predicted[:5]
# Out:
# array([[1427.8215, 1422.644 ],
#        [1426.5845, 1421.4971],
#        [1425.2609, 1419.6366],
#        [1438.3596, 1431.7725],
#        [1439.3722, 1433.3464]], dtype=float32)

# %% [markdown]
# ##  VISUALIZING ACTUAL VS PREDICTED DATA

# %%
# Merging actual and predicted data for better visualization
df_merge = pd.concat([df.iloc[-264:].copy(),
                          pd.DataFrame(test_inverse_predicted,columns=['open_predicted','close_predicted'],
                                       index=df.iloc[-264:].index)], axis=1)

# %%
# Inversing normalization/scaling 
df_merge[['open','close']] = MMS.inverse_transform(df_merge[['open','close']])
df_merge.head()
# Out:
#                open    close  open_predicted  close_predicted
# date
# 2020-05-27  1417.25  1417.84     1427.821533      1422.644043
# 2020-05-28  1396.86  1416.73     1426.584473      1421.497070
# 2020-05-29  1416.94  1428.92     1425.260864      1419.636597
# 2020-06-01  1418.39  1431.82     1438.359619      1431.772461
# 2020-06-02  1430.55  1439.22     1439.372192      1433.346436

# %%
# plotting the actual open and predicted open prices on date index
df_merge[['open','open_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for open price',size=15)
plt.show()

# %%
# plotting the actual close and predicted close prices on date index 
df_merge[['close','close_predicted']].plot(figsize=(10,6))
plt.xticks(rotation=45)
plt.xlabel('Date',size=15)
plt.ylabel('Stock Price',size=15)
plt.title('Actual vs Predicted for close price',size=15)
plt.show()

# %% [markdown]
# ## STEP 6. PREDICTING UPCOMING 10 DAYS

# %%
# Creating a dataframe and adding 10 days to existing index 

df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
                                        index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
df_merge['2021-06-09':'2021-06-16']
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1664\679996223.py in ?()
#       1 # Creating a dataframe and adding 10 days to existing index
#       2
# ----> 3 df_merge = df_merge.append(pd.DataFrame(columns=df_merge.columns,
#       4                                         index=pd.date_range(start=df_merge.index[-1], periods=11, freq='D', closed='right')))
#       5 df_merge['2021-06-09':'2021-06-16']
#
# c:\Users\tarun\anaconda3\Lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6295             and name not in self._accessors
#    6296             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297         ):
#    6298             return self[name]
# -> 6299         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
# creating a DataFrame and filling values of open and close column
upcoming_prediction = pd.DataFrame(columns=['open','close'],index=df_merge.index)
upcoming_prediction.index=pd.to_datetime(upcoming_prediction.index)

# %%
curr_seq = test_seq[-1:]

for i in range(-10,0):
  up_pred = model.predict(curr_seq)
  upcoming_prediction.iloc[i] = up_pred
  curr_seq = np.append(curr_seq[0][1:],up_pred,axis=0)
  curr_seq = curr_seq.reshape(test_seq[-1:].shape)
# Out:
# 1/1 [==============================] - 0s 13ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 28ms/step
# 1/1 [==============================] - 0s 28ms/step

# %%
# inversing Normalization/scaling
upcoming_prediction[['open','close']] = MMS.inverse_transform(upcoming_prediction[['open','close']])

# %%
# plotting Upcoming Open price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'open'],label='Current Open Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'open'],label='Upcoming Open Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming Open price prediction',size=15)
ax.legend()
fig.show()

# %%
# plotting Upcoming Close price on date index
fig,ax=plt.subplots(figsize=(10,5))
ax.plot(df_merge.loc['2021-04-01':,'close'],label='Current close Price')
ax.plot(upcoming_prediction.loc['2021-04-01':,'close'],label='Upcoming close Price')
plt.setp(ax.xaxis.get_majorticklabels(), rotation=45)
ax.set_xlabel('Date',size=15)
ax.set_ylabel('Stock Price',size=15)
ax.set_title('Upcoming close price prediction',size=15)
ax.legend()
fig.show()

# %% [markdown]
# # **THANK YOU!**
